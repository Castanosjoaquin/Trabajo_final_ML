# %% [markdown]
# # Exploratory Data Analysis
#
# Notebook de exploración para el panel procesado del proyecto.
#
# Objetivos:
# - cargar `data/processed/panel_nucleo.parquet`
# - revisar cobertura, estructura y valores faltantes
# - explorar campañas, cultivos y split temporal
# - dejar una base mínima para modelado posterior

# %% [markdown]
# ## Vista general
#
# Este bloque resume tamaño, tipos de datos, cobertura por split y las variables objetivo.

# %% [markdown]
# ## Exploración rápida
#
# Distribución del rendimiento y relación simple con algunas variables numéricas.

# %% [markdown]
# Ahora que ya estamos en tema, arma un eda( mira distribuciones de features, relacioens entre estas, como se comporta el rinde en las distintas campanas, anos, y demas, proba ver como se comportan las featues por fuente, proba relaciona fuentes, se inteligente pensa qye es necesario ver para el eda y como se comportan las feature teniendo en cuenta nuestro objeticvo del proyecto) Tene en cuenta en ndvi tiene datos desde 2002 y nostros vemos desde 1981( no quiero que dropees nans solo tene cuidado con el eda)

# %% [markdown]
# ## Siguientes pasos
#
# A partir de esta base, se puede agregar un bloque de modelado con un baseline temporal simple, validación por split y métricas por cultivo.
