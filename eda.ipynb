# %%
import pandas as pd

df = pd.read_parquet("data/processed/panel_nucleo.parquet")
print(df.shape)
print(df.columns.tolist())
# Out:
# (2287, 132)
# ...

# %%
df.head()
# Out:
#   cultivo  campania_inicio     provincia departamento  sup_sembrada_ha  \
# 0    maiz             1981  BUENOS AIRES    Arrecifes            28000
# 1    maiz             1982  BUENOS AIRES    Arrecifes            18000
# 2    maiz             1983  BUENOS AIRES    Arrecifes            19000
# 3    maiz             1984  BUENOS AIRES    Arrecifes            20000
# 4    maiz             1985  BUENOS AIRES    Arrecifes            22000
#
#    sup_cosechada_ha  produccion_tn  rinde_kgha  lat_centroide  lon_centroide  \
# 0           28000.0       117600.0      4200.0         -34.07          -60.1
# 1           15000.0        37500.0      2500.0         -34.07          -60.1
# 2           18700.0        74000.0      3957.0         -34.07          -60.1
# 3           20000.0        75600.0      3780.0         -34.07          -60.1
# 4           22000.0        97800.0      4445.0         -34.07          -60.1
#
# ...

# %%
y = df["rinde_kgha"]
print(y)
# Out:
# 0       4200.0
# 1       2500.0
# 2       3957.0
# 3       3780.0
# 4       4445.0
#          ...
# 2282    2507.0
# 2283    2024.0
# 2284    1139.0
# 2285    3590.0
# 2286    3726.0
# Name: rinde_kgha, Length: 2287, dtype: float64

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(
    df,
    title="Reporte EDA completo",
    explorative=True
)

profile.to_notebook_iframe()
profile.to_file("reporte_eda.html")
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
profile = ProfileReport(df.sample(10000, random_state=42), title="EDA", explorative=True)
